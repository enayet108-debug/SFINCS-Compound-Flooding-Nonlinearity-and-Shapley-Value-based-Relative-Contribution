# %%
# This code was primarily developed by Dr Wonhyun Lee, Research Assistant Professor, UT Austin
from os.path import join
import matplotlib.pyplot as plt
from hydromt_sfincs import SfincsModel, utils
import os
import numpy as np
import xarray as xr
# import dfm_tools as dfmt
import random
# %matplotlib qt

# %%
# Specify the path to the NetCDF file
# This is the netCDF file directly downloaded from the ERA5 website
root = "era5_hourly_data_beryl.nc"

# %%
# Open the dataset
dataset = xr.open_dataset(root)
dataset
# Out:
# <xarray.Dataset> Size: 542kB
# Dimensions:     (valid_time: 264, latitude: 13, longitude: 13)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 2kB 2024-07-01 ... 2024-07-11T23:...
#   * latitude    (latitude) float64 104B 31.0 30.75 30.5 ... 28.5 28.25 28.0
#   * longitude   (longitude) float64 104B -96.0 -95.75 -95.5 ... -93.25 -93.0
#     expver      (valid_time) <U4 4kB ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 178kB ...
#     v10         (valid_time, latitude, longitude) float32 178kB ...
#     tp          (valid_time, latitude, longitude) float32 178kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
lat = dataset['latitude'].values
lon = dataset['longitude'].values
precip = dataset['tp'].values
time = dataset['valid_time'].values

# %%
# Create a DataArray with the precipitation data
n1_zsmax = xr.DataArray(
    precip, 
    name="precip", 
    dims=("time", "latitude", "longitude"), 
    coords={"latitude": lat, "longitude": lon, "time": time}, 
    attrs={"units": "m", "long_name": "Total Precipitation", "_FillValue": "NaN", "coordinates": "spatial_ref"}
)

# %%
# Write the CRS and save to NetCDF
# Use the correct epsg code for your study area
n1_zsmax.rio.write_crs("epsg:4326", inplace=True)
n1_zsmax.to_netcdf("Beryl_precip_2.nc")
